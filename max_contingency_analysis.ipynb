# %%
def pf_enviroment(dig_path):
    sys.path.append(dig_path)
    os.environ['PATH'] += f';{dig_path}'
    print(f"PowerFactory environment initialized with path: {dig_path}")

# %%
def get_application():
    """
    Initializes the PowerFactory application instance.
    """
    app = pf.GetApplication()
    current_user = app.GetCurrentUser()
    print(f"Initialize successfully and the  current user is {current_user}")
    return app

# %%
def activate_project(project_name):
    # Intentar activar el proyecto
    project = app.ActivateProject(project_name)

    # Verificar si el proyecto se activó correctamente
    if project == 0:
        print(f"Proyecto '{project_name}' activado con éxito.")
    else:
        print(f"No se pudo activar el proyecto '{project_name}'. Verifica si el nombre es correcto.")
    return project

# %%
def list_and_select_study_case(app, study_case_name: str):
    """
    Lists all study cases and activates a specified study case.
    """
    study_case_fldr = app.GetProjectFolder('study')
    study_cases = study_case_fldr.GetContents('*.Intcase', 0)
    print('List of study cases:')
    for case in study_cases:
        print(case.loc_name)
    selected_case = next((case for case in study_cases if case.loc_name == study_case_name), None)
    if selected_case:
        selected_case.Activate()
        print(f"Study case '{study_case_name}' activated.")
    else:
        print(f"Study case '{study_case_name}' not found.")
    return app.GetActiveStudyCase()

# %%
def list_and_activate_operation_scenario(app, scenario_name: str):
    """
    Lists all operation scenarios and activates a specified one.
    """
    operation_scenarios_folder = app.GetProjectFolder('scen')
    print('List of operation scenarios:')
    for scenario in operation_scenarios_folder.GetChildren(1):
        print(scenario.loc_name)
    selected_scenario = next((s for s in operation_scenarios_folder.GetChildren(1) if s.loc_name == scenario_name), None)
    if selected_scenario:
        selected_scenario.Activate()
        print(f"Operation scenario '{scenario_name}' activated.")
    else:
        print(f"Operation scenario '{scenario_name}' not found.")
    return selected_scenario

# %% [markdown]
# ---

# %%
def create_static_generator(network_data, hoja_name, barra_name, potencia_activa, factor_potencia):
    print(f"Creando generador estático en la barra '{barra_name}' con potencia activa {potencia_activa} MW y factor de potencia {factor_potencia}.")
    potencia_aparente = potencia_activa / factor_potencia
    potencia_reactiva_max = math.sqrt(potencia_aparente*2 - potencia_activa*2)
    potencia_reactiva_min = -potencia_reactiva_max

    # Obtener la hoja correspondiente
    print(f"Buscando hoja '{hoja_name}' en 'Network Data'.")
    hoja = network_data.GetContents(hoja_name, 1)[0]
    if not hoja:
        print(f"No se encontró la hoja '{hoja_name}' en 'Network Data'.")
        return None, None, None, None

    # Buscar la barra correspondiente
    bus = None
    for b in app.GetCalcRelevantObjects('*.ElmTerm'):
        if b.loc_name == barra_name:
            bus = b
            break

    if bus:
        print(f"Barra '{barra_name}' encontrada. Creando cubículo y generador estático.")
        
        # Crear el cubículo y conectarlo a la barra
        cubicle = bus.CreateObject('StaCubic', 'Cubicle_Generador')
        cubicle.bus1 = bus
        
        if cubicle:
            print(f"Cubículo creado en la barra '{barra_name}' y conectado a la barra.")
        else:
            print(f"Error al crear el cubículo en la barra '{barra_name}'.")

        # Crear el switch asociado
        switcher = cubicle.CreateObject('StaSwitch', 'Switcher_Generador')
        switcher.on_off = 1

        # Crear el generador estático y conectarlo al cubículo
        static_generator = hoja.CreateObject('ElmGenstat', 'Generador_Estatico')
        static_generator.SetAttribute('sgn', potencia_aparente)
        static_generator.SetAttribute('e:pgini', potencia_activa)
        static_generator.SetAttribute('cosn', factor_potencia)
        static_generator.SetAttribute('av_mode', 'constv')
        static_generator.term = cubicle
        static_generator.SetAttribute('usetp', 1)
        static_generator.SetAttribute('cQ_max', potencia_reactiva_max)
        static_generator.SetAttribute('cQ_min', potencia_reactiva_min)
        cubicle.obj_id = static_generator

        print(f"Ejecutando flujo de potencia para la barra '{barra_name}'.")
        power_flow = app.GetFromStudyCase('ComLdf')
        power_flow.Execute()

        bus_voltage = bus.GetAttribute('m:u')
        potencia_activa_generada = static_generator.GetAttribute('m:P:bus1')
        potencia_reactiva_generada = static_generator.GetAttribute('m:Q:bus1')

        print(f"Generador estático creado: Voltaje barra = {bus_voltage}, P generada = {potencia_activa_generada}, Q generada = {potencia_reactiva_generada}")
        return bus_voltage, potencia_activa_generada, potencia_reactiva_generada, static_generator, cubicle
    else:
        print(f"Barra '{barra_name}' no encontrada.")
        return None, None, None, None

# %%
def run_contingency_analysis():
    print("Iniciando análisis de contingencia N-1.")
    app.ClearOutputWindow()
    
    # Get the contingency analysis module
    contingency_analysis = app.GetFromStudyCase('*.ComSimoutage')
    contingency_analysis.iopt_Linear = 0
    contingency_analysis.loadmax = 50
    contingency_analysis.vlmin = 0.9
    contingency_analysis.vlmax = 1.1
    contingency_analysis.vmax_step = 5

    contingency_analysis.Execute()
    
    elmres = app.GetFromStudyCase('Contingency Analysis AC.ElmRes')
    comres = app.GetFromStudyCase('ComRes')
    comres.iopt_exp = 6
    comres.iopt_csel = 0
    comres.pResult = elmres
    comres.f_name = r'Resultados.csv'
    comres.Execute()

    print("Cargando resultados del archivo 'Resultados.csv'.")
    df = pd.read_csv('Resultados.csv', encoding='latin1', low_memory=False)
    return df

# %%
def process_cargabilidad(df):
    print("Procesando resultados de cargabilidad.")
    line_names = df.columns
    last_row = df.iloc[-1]
    line_load_df = pd.DataFrame({'Linea': line_names, 'Cargabilidad_Maxima': last_row})
    line_load_df = line_load_df[line_load_df['Cargabilidad_Maxima'] != '----']
    line_load_df['Cargabilidad_Maxima'] = pd.to_numeric(line_load_df['Cargabilidad_Maxima'], errors='coerce')
    line_load_df = line_load_df.dropna(subset=['Cargabilidad_Maxima'])
    line_load_df = line_load_df[~line_load_df['Linea'].str.contains('Study Cases', case=False)]
    line_load_df['Linea'] = line_load_df['Linea'].apply(lambda x: x.split('\\')[-1])
    line_load_df['Linea'] = line_load_df['Linea'].str.replace('.ElmLne', '', regex=False)
    
    # Eliminar las líneas que contienen '69 kV', '34.5 kV', o '4.16 kV'
    line_load_df = line_load_df[~line_load_df['Linea'].str.contains('69 kV|34.5 kV|4.16 kV', case=False)]
    
    line_load_df = line_load_df.sort_values(by='Cargabilidad_Maxima', ascending=False).reset_index(drop=True)
    print("Procesamiento de cargabilidad completado.")
    return line_load_df

# %%
def optimize_generators_for_substations(substations, network_data,hoja, initial_potencia=1, factor_potencia=0.95, max_cargabilidad=110, threshold_inconvergence=10):
    """
    Itera sobre cada subestación, agregando un generador, corriendo el análisis de contingencia y verificando el 
    máximo de potencia que puede soportar sin exceder el 110% de cargabilidad en ninguna línea.
    """
    results = []  # Lista para almacenar los resultados

    for substation in substations:
        current_potencia = initial_potencia
        print(f"Optimizando generador para la subestación '{substation}'.")

        # Crear generador inicial
        bus_voltage, p_gen, q_gen, static_generator, cubicle = create_static_generator(network_data, hoja, substation, current_potencia, factor_potencia)
        if static_generator is None:
            print(f"Error: No se pudo crear el generador en la subestación '{substation}'.")
            continue

        last_max_line_load = None

        while True:
            # Ejecutar el análisis de contingencia N-1 y obtener los resultados
            print("Ejecutando análisis de contingencia.")
            df = run_contingency_analysis()
            line_load_df = process_cargabilidad(df)

            # Verificar si alguna línea excede el 110% de cargabilidad
            max_line_load = line_load_df['Cargabilidad_Maxima'].max()
            max_line = line_load_df[line_load_df['Cargabilidad_Maxima'] == max_line_load]['Linea'].values[0]

            print(f"Subestación {substation}: Potencia actual = {current_potencia} MW, Max cargabilidad = {max_line_load}%, Línea = {max_line}")

            # Detectar inconvergencia si el incremento supera el umbral definido y si la cargabilidad es mayor a 110%
            if last_max_line_load is not None and (max_line_load - last_max_line_load) > threshold_inconvergence and max_line_load > max_cargabilidad:
                print(f"Advertencia: Inconvergencia detectada en la subestación '{substation}'. La cargabilidad saltó más del {threshold_inconvergence}% y superó el 110%. Aumentando potencia y volviendo a intentar.")
                # Aumentar la potencia en 1 MW y continuar
                current_potencia += 1
                potencia_aparente = current_potencia / factor_potencia
                potencia_reactiva_max = math.sqrt(potencia_aparente*2 - current_potencia*2)
                potencia_reactiva_min = -potencia_reactiva_max
                static_generator.SetAttribute('sgn', potencia_aparente)
                static_generator.SetAttribute('e:pgini', current_potencia)
                static_generator.SetAttribute('cQ_max', potencia_reactiva_max)
                static_generator.SetAttribute('cQ_min', potencia_reactiva_min)

                power_flow = app.GetFromStudyCase('ComLdf')
                power_flow.Execute()

                continue  # Seguir con la próxima iteración con la nueva potencia

            last_max_line_load = max_line_load

            if max_line_load > max_cargabilidad:
                print(f"Subestación {substation}: Potencia máxima segura = {current_potencia - 1} MW, Línea crítica = {max_line}")

                # Guardar el resultado en la lista
                results.append({
                    'Subestacion': substation,
                    'Potencia Maxima': current_potencia - 1,
                    'Linea Critica': max_line,
                    'Cargabilidad Maxima': last_max_line_load
                })

                # Eliminar el generador estático y el cubículo
                print(f"Eliminando generador estático y cubículo en la subestación '{substation}'.")
                static_generator.Delete()
                cubicle.Delete()

                break

            # Aumentar la potencia del generador estático existente
            current_potencia += 1
            potencia_aparente = current_potencia / factor_potencia
            potencia_reactiva_max = math.sqrt(potencia_aparente*2 - current_potencia*2)
            potencia_reactiva_min = -potencia_reactiva_max
            static_generator.SetAttribute('sgn', potencia_aparente)
            static_generator.SetAttribute('e:pgini', current_potencia)
            static_generator.SetAttribute('cQ_max', potencia_reactiva_max)
            static_generator.SetAttribute('cQ_min', potencia_reactiva_min)

            # Ejecutar el flujo de potencia nuevamente para aplicar los cambios
            power_flow = app.GetFromStudyCase('ComLdf')
            power_flow.Execute()

            print(f"Subestación {substation}: Aumentando potencia a {current_potencia} MW.")

    # Convertir los resultados a un DataFrame
    df_results = pd.DataFrame(results)
    print("Resultados finales:")
    print(df_results)

    return df_results

# %% [markdown]
# ---

# %%
import os
import sys

# Añadir la ruta del entorno de PowerFactory
dig_path = r'C:\Program Files\DIgSILENT\PowerFactory 2021 SP2\Python\3.9'
pf_enviroment(dig_path)
# Out:
# PowerFactory environment initialized with path: C:\Program Files\DIgSILENT\PowerFactory 2021 SP2\Python\3.9

# %%
import powerfactory as pf
import matplotlib.pyplot as plt

app = get_application()
# Nombre del proyecto a activar
project_name = "39 Bus New England System"
project = activate_project(project_name)
# Activate the desired study case
study_case_name = "1. Power Flow"  # Replace with your specific case name
active_study_case = list_and_select_study_case(app, study_case_name)
# Activate the desired operation scenario
operation_scenario_name = "Ene_Bloque_3_dem_min_diurna_2028"
active_scenario = list_and_activate_operation_scenario(app, operation_scenario_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import powerfactory as pf
#       2 import matplotlib.pyplot as plt
#       4 app = get_application()
#
# ModuleNotFoundError: No module named 'powerfactory'

# %%
import pandas as pd
import math

# Ejecución
print("Iniciando optimización de generadores en las subestaciones.")

substations = [
    # "138 kV Agua Clara",
    # "138 kV Dajabón",
    # "138 kV Dominicana Azul",
    # "138 kV El Naranjo B2 Sec A",
    # "138 kV Esperanza",
    # "138 kV Frontera",
    # "138 kV Gaspar Hernandez",
    # "138 kV Guanillo",
    # "138 kV Guayubín",
    # "138 kV La Gallera Sec B",
    # "138 kV La Vega II Sec A",
    # "138 kV Los Guzmancito",
    # "138 kV Matrisol",
    # "138 kV Moca",
    # "138 kV Monción",
    # "138 kV Monte Cristi",
    # "138 kV Nagua 2",
    # "138 kV Navarrete 2 B1 Sec A",
    # "138 kV Nibaje",
    # "138 kV PSF Manzanillo",
    # "138 kV Palamara B1",
    # "138 kV Payita",
    # "138 kV Pimentel Sec B",
    # "138 kV Playa Dorada",
    # "138 kV Puerto Plata 2 B1 Sec A",
    # "138 kV Río San Juan",
    # "138 kV SFM BT",
    # "138 kV Sajoma",
    # "138 kV Salcedo",
    # "138 kV Santiago Norte Sec A",
    # "138 kV Santiago Rodríguez",
    # "138 kV Solsur",
    # "138 kV Sánchez",
    # "138 kV Tavera B2",
    # "138 kV Valverde Mao BT",
    # "138 kV ZF Santiago B1",
    # "138 kV Pimentel Energy",
    # "bonao2",
    "bonao3",
    "canabacoa",
    "guayubin"
]



project = app.GetActiveProject()
network_data = project.GetContents('Network Model.IntPrjfolder\\Network Data', 1)[0]
hoja = 'NORTE'
initial_potencia = 1
factor_potencia = 0.95
max_cargabilidad = 110
threshold_inconvergence = 10
df_results = optimize_generators_for_substations(substations, network_data, hoja, initial_potencia, factor_potencia, max_cargabilidad, threshold_inconvergence)

print("Proceso completado.")
# Out:
# Iniciando optimización de generadores en las subestaciones.
# Optimizando generador para la subestación '138 kV Santiago Norte Sec A'.
# Creando generador estático en la barra '138 kV Santiago Norte Sec A' con potencia activa 1 MW y factor de potencia 0.95.
# Buscando hoja 'NORTE' en 'Network Data'.
# Barra '138 kV Santiago Norte Sec A' encontrada. Creando cubículo y generador estático.
# Cubículo creado en la barra '138 kV Santiago Norte Sec A' y conectado a la barra.
# Ejecutando flujo de potencia para la barra '138 kV Santiago Norte Sec A'.
# Generador estático creado: Voltaje barra = 1.0000000000097553, P generada = 0.9999999943023692, Q generada = -19.030865483746442
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 1 MW, Max cargabilidad = 107.457591%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 2 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 2 MW, Max cargabilidad = 107.451622%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 3 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 3 MW, Max cargabilidad = 107.445654%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 4 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 4 MW, Max cargabilidad = 107.439688%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 5 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 5 MW, Max cargabilidad = 107.433725%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 6 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 6 MW, Max cargabilidad = 107.427763%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 7 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 7 MW, Max cargabilidad = 107.421804%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 8 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 8 MW, Max cargabilidad = 107.415846%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 9 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 9 MW, Max cargabilidad = 107.409891%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 10 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 10 MW, Max cargabilidad = 107.403938%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 11 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 11 MW, Max cargabilidad = 107.397987%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 12 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 12 MW, Max cargabilidad = 107.392038%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 13 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 13 MW, Max cargabilidad = 107.386091%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 14 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 14 MW, Max cargabilidad = 107.380146%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 15 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 15 MW, Max cargabilidad = 107.374203%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 16 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 16 MW, Max cargabilidad = 107.368262%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 17 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 17 MW, Max cargabilidad = 107.362323%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 18 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 18 MW, Max cargabilidad = 107.356387%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 19 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 19 MW, Max cargabilidad = 107.350452%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 20 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 20 MW, Max cargabilidad = 107.34452%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 21 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 21 MW, Max cargabilidad = 107.33859%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 22 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 22 MW, Max cargabilidad = 107.332661%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 23 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 23 MW, Max cargabilidad = 107.326735%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 24 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 24 MW, Max cargabilidad = 107.320811%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 25 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 25 MW, Max cargabilidad = 107.314889%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 26 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 26 MW, Max cargabilidad = 107.308969%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 27 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 27 MW, Max cargabilidad = 107.303051%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 28 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 28 MW, Max cargabilidad = 107.297136%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 29 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 29 MW, Max cargabilidad = 107.291222%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 30 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 30 MW, Max cargabilidad = 107.285311%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 31 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 31 MW, Max cargabilidad = 107.279401%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 32 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 32 MW, Max cargabilidad = 107.273494%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 33 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 33 MW, Max cargabilidad = 107.267589%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 34 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 34 MW, Max cargabilidad = 107.261686%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 35 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 35 MW, Max cargabilidad = 107.255785%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 36 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 36 MW, Max cargabilidad = 107.249886%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 37 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 37 MW, Max cargabilidad = 107.243989%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 38 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 38 MW, Max cargabilidad = 107.238094%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 39 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 39 MW, Max cargabilidad = 107.232202%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 40 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 40 MW, Max cargabilidad = 107.226311%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 41 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 41 MW, Max cargabilidad = 107.220423%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 42 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 42 MW, Max cargabilidad = 107.214537%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 43 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 43 MW, Max cargabilidad = 107.208653%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 44 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 44 MW, Max cargabilidad = 107.202771%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 45 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 45 MW, Max cargabilidad = 107.196891%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 46 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 46 MW, Max cargabilidad = 107.191013%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 47 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 47 MW, Max cargabilidad = 107.185138%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 48 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 48 MW, Max cargabilidad = 107.179264%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 49 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 49 MW, Max cargabilidad = 107.173393%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 50 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 50 MW, Max cargabilidad = 107.167524%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 51 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 51 MW, Max cargabilidad = 107.161657%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 52 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 52 MW, Max cargabilidad = 107.155792%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 53 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 53 MW, Max cargabilidad = 107.149929%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 54 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 54 MW, Max cargabilidad = 107.144069%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 55 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 55 MW, Max cargabilidad = 107.13821%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 56 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 56 MW, Max cargabilidad = 107.132354%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 57 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 57 MW, Max cargabilidad = 107.1265%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 58 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 58 MW, Max cargabilidad = 107.120648%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 59 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 59 MW, Max cargabilidad = 107.114798%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 60 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 60 MW, Max cargabilidad = 107.10895%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 61 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 61 MW, Max cargabilidad = 107.103105%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 62 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 62 MW, Max cargabilidad = 107.097261%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 63 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 63 MW, Max cargabilidad = 107.09142%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 64 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 64 MW, Max cargabilidad = 107.085581%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 65 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 65 MW, Max cargabilidad = 107.079744%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 66 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 66 MW, Max cargabilidad = 107.073909%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 67 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 67 MW, Max cargabilidad = 107.068077%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 68 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 68 MW, Max cargabilidad = 107.062246%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 69 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 69 MW, Max cargabilidad = 107.056418%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 70 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 70 MW, Max cargabilidad = 107.050592%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 71 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 71 MW, Max cargabilidad = 107.044768%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 72 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 72 MW, Max cargabilidad = 107.038947%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 73 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 73 MW, Max cargabilidad = 107.033127%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 74 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 74 MW, Max cargabilidad = 107.02731%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 75 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 75 MW, Max cargabilidad = 107.021494%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 76 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 76 MW, Max cargabilidad = 107.015681%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 77 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 77 MW, Max cargabilidad = 107.009871%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 78 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 78 MW, Max cargabilidad = 107.004062%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 79 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 79 MW, Max cargabilidad = 106.998256%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 80 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 80 MW, Max cargabilidad = 106.992451%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 81 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 81 MW, Max cargabilidad = 106.986649%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 82 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 82 MW, Max cargabilidad = 106.98085%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 83 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 83 MW, Max cargabilidad = 106.975052%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 84 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 84 MW, Max cargabilidad = 106.969257%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 85 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 85 MW, Max cargabilidad = 106.963463%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 86 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 86 MW, Max cargabilidad = 106.957672%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 87 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 87 MW, Max cargabilidad = 106.951883%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 88 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 88 MW, Max cargabilidad = 106.946097%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 89 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 89 MW, Max cargabilidad = 106.940312%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 90 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 90 MW, Max cargabilidad = 106.93453%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 91 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 91 MW, Max cargabilidad = 106.92875%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 92 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 92 MW, Max cargabilidad = 106.922973%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 93 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 93 MW, Max cargabilidad = 106.917197%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 94 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 94 MW, Max cargabilidad = 106.911424%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 95 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 95 MW, Max cargabilidad = 106.905653%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 96 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 96 MW, Max cargabilidad = 106.899884%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 97 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 97 MW, Max cargabilidad = 106.894117%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 98 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 98 MW, Max cargabilidad = 106.888353%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 99 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 99 MW, Max cargabilidad = 106.882591%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 100 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 100 MW, Max cargabilidad = 106.876831%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 101 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 101 MW, Max cargabilidad = 106.871073%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 102 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 102 MW, Max cargabilidad = 106.865318%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 103 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 103 MW, Max cargabilidad = 106.859565%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 104 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 104 MW, Max cargabilidad = 106.853814%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 105 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 105 MW, Max cargabilidad = 106.848065%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 106 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 106 MW, Max cargabilidad = 106.842318%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 107 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 107 MW, Max cargabilidad = 106.836574%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 108 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 108 MW, Max cargabilidad = 106.830832%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 109 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 109 MW, Max cargabilidad = 106.825093%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 110 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 110 MW, Max cargabilidad = 106.819355%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 111 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 111 MW, Max cargabilidad = 106.81362%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 112 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 112 MW, Max cargabilidad = 106.807887%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 113 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 113 MW, Max cargabilidad = 106.802157%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 114 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 114 MW, Max cargabilidad = 106.796428%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 115 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 115 MW, Max cargabilidad = 106.790702%, Línea = 138 kV Pimentel â SFM
# Subestación 138 kV Santiago Norte Sec A: Aumentando potencia a 116 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Santiago Norte Sec A: Potencia actual = 116 MW, Max cargabilidad = 106.784979%, Línea = 138 kV Pimentel â SFM
# ...
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 176 MW, Max cargabilidad = 107.036624%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 177 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 177 MW, Max cargabilidad = 107.034416%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 178 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 178 MW, Max cargabilidad = 107.032209%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 179 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 179 MW, Max cargabilidad = 107.030003%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 180 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 180 MW, Max cargabilidad = 107.027797%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 181 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 181 MW, Max cargabilidad = 107.025592%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 182 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 182 MW, Max cargabilidad = 107.023387%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 183 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 183 MW, Max cargabilidad = 107.021183%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 184 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 184 MW, Max cargabilidad = 107.01898%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 185 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 185 MW, Max cargabilidad = 107.016778%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 186 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 186 MW, Max cargabilidad = 107.014576%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 187 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 187 MW, Max cargabilidad = 107.012375%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 188 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 188 MW, Max cargabilidad = 107.010174%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 189 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 189 MW, Max cargabilidad = 107.007974%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 190 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 190 MW, Max cargabilidad = 107.005775%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 191 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 191 MW, Max cargabilidad = 107.003576%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 192 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 192 MW, Max cargabilidad = 107.001379%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 193 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 193 MW, Max cargabilidad = 106.999181%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 194 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 194 MW, Max cargabilidad = 106.996985%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 195 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 195 MW, Max cargabilidad = 106.994789%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 196 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 196 MW, Max cargabilidad = 106.992594%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 197 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 197 MW, Max cargabilidad = 106.990399%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 198 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 198 MW, Max cargabilidad = 106.988205%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 199 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 199 MW, Max cargabilidad = 106.986012%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 200 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 200 MW, Max cargabilidad = 106.983819%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 201 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 201 MW, Max cargabilidad = 106.981627%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 202 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 202 MW, Max cargabilidad = 106.979436%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 203 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 203 MW, Max cargabilidad = 106.977246%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 204 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 204 MW, Max cargabilidad = 106.975056%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 205 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 205 MW, Max cargabilidad = 106.972866%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 206 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 206 MW, Max cargabilidad = 106.970678%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 207 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 207 MW, Max cargabilidad = 106.96849%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 208 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 208 MW, Max cargabilidad = 106.966303%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 209 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 209 MW, Max cargabilidad = 106.964116%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 210 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 210 MW, Max cargabilidad = 106.96193%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 211 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 211 MW, Max cargabilidad = 106.959745%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 212 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 212 MW, Max cargabilidad = 106.957561%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 213 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 213 MW, Max cargabilidad = 106.955377%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 214 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 214 MW, Max cargabilidad = 106.953193%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 215 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 215 MW, Max cargabilidad = 106.951011%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 216 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 216 MW, Max cargabilidad = 106.948829%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 217 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 217 MW, Max cargabilidad = 106.946648%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 218 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 218 MW, Max cargabilidad = 106.944467%, Línea = 138 kV Pimentel â SFM
# Subestación bonao3: Aumentando potencia a 219 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación bonao3: Potencia actual = 219 MW, Max cargabilidad = 106.942288%, Línea = 138 kV Pimentel â SFM
