# %%
def pf_enviroment(dig_path):
    sys.path.append(dig_path)
    os.environ['PATH'] += f';{dig_path}'
    print(f"PowerFactory environment initialized with path: {dig_path}")

# %%
def get_application():
    """
    Initializes the PowerFactory application instance.
    """
    app = pf.GetApplication()
    current_user = app.GetCurrentUser()
    print(f"Initialize successfully and the  current user is {current_user}")
    return app

# %%
def activate_project(project_name):
    # Intentar activar el proyecto
    project = app.ActivateProject(project_name)

    # Verificar si el proyecto se activó correctamente
    if project == 0:
        print(f"Proyecto '{project_name}' activado con éxito.")
    else:
        print(f"No se pudo activar el proyecto '{project_name}'. Verifica si el nombre es correcto.")
    return project

# %%
def list_and_select_study_case(app, study_case_name: str):
    """
    Lists all study cases and activates a specified study case.
    """
    study_case_fldr = app.GetProjectFolder('study')
    study_cases = study_case_fldr.GetContents('*.Intcase', 0)
    print('List of study cases:')
    for case in study_cases:
        print(case.loc_name)
    selected_case = next((case for case in study_cases if case.loc_name == study_case_name), None)
    if selected_case:
        selected_case.Activate()
        print(f"Study case '{study_case_name}' activated.")
    else:
        print(f"Study case '{study_case_name}' not found.")
    return app.GetActiveStudyCase()

# %%
def list_and_activate_operation_scenario(app, scenario_name: str):
    """
    Lists all operation scenarios and activates a specified one.
    """
    operation_scenarios_folder = app.GetProjectFolder('scen')
    print('List of operation scenarios:')
    for scenario in operation_scenarios_folder.GetChildren(1):
        print(scenario.loc_name)
    selected_scenario = next((s for s in operation_scenarios_folder.GetChildren(1) if s.loc_name == scenario_name), None)
    if selected_scenario:
        selected_scenario.Activate()
        print(f"Operation scenario '{scenario_name}' activated.")
    else:
        print(f"Operation scenario '{scenario_name}' not found.")
    return selected_scenario

# %% [markdown]
# ---

# %%
def create_static_generator(network_data, hoja_name, barra_name, potencia_activa, factor_potencia):
    print(f"Creando generador estático en la barra '{barra_name}' con potencia activa {potencia_activa} MW y factor de potencia {factor_potencia}.")
    potencia_aparente = potencia_activa / factor_potencia
    potencia_reactiva_max = math.sqrt(potencia_aparente*2 - potencia_activa*2)
    potencia_reactiva_min = -potencia_reactiva_max

    # Obtener la hoja correspondiente
    print(f"Buscando hoja '{hoja_name}' en 'Network Data'.")
    hoja = network_data.GetContents(hoja_name, 1)[0]
    if not hoja:
        print(f"No se encontró la hoja '{hoja_name}' en 'Network Data'.")
        return None, None, None, None

    # Buscar la barra correspondiente
    bus = None
    for b in app.GetCalcRelevantObjects('*.ElmTerm'):
        if b.loc_name == barra_name:
            bus = b
            break

    if bus:
        print(f"Barra '{barra_name}' encontrada. Creando cubículo y generador estático.")
        
        # Crear el cubículo y conectarlo a la barra
        cubicle = bus.CreateObject('StaCubic', 'Cubicle_Generador')
        cubicle.bus1 = bus
        
        if cubicle:
            print(f"Cubículo creado en la barra '{barra_name}' y conectado a la barra.")
        else:
            print(f"Error al crear el cubículo en la barra '{barra_name}'.")

        # Crear el switch asociado
        switcher = cubicle.CreateObject('StaSwitch', 'Switcher_Generador')
        switcher.on_off = 1

        # Crear el generador estático y conectarlo al cubículo
        static_generator = hoja.CreateObject('ElmGenstat', 'Generador_Estatico')
        static_generator.SetAttribute('sgn', potencia_aparente)
        static_generator.SetAttribute('e:pgini', potencia_activa)
        static_generator.SetAttribute('cosn', factor_potencia)
        static_generator.SetAttribute('av_mode', 'constv')
        static_generator.term = cubicle
        static_generator.SetAttribute('usetp', 1)
        static_generator.SetAttribute('cQ_max', potencia_reactiva_max)
        static_generator.SetAttribute('cQ_min', potencia_reactiva_min)
        cubicle.obj_id = static_generator

        print(f"Ejecutando flujo de potencia para la barra '{barra_name}'.")
        power_flow = app.GetFromStudyCase('ComLdf')
        power_flow.Execute()

        bus_voltage = bus.GetAttribute('m:u')
        potencia_activa_generada = static_generator.GetAttribute('m:P:bus1')
        potencia_reactiva_generada = static_generator.GetAttribute('m:Q:bus1')

        print(f"Generador estático creado: Voltaje barra = {bus_voltage}, P generada = {potencia_activa_generada}, Q generada = {potencia_reactiva_generada}")
        return bus_voltage, potencia_activa_generada, potencia_reactiva_generada, static_generator, cubicle
    else:
        print(f"Barra '{barra_name}' no encontrada.")
        return None, None, None, None

# %%
def run_contingency_analysis():
    print("Iniciando análisis de contingencia N-1.")
    app.ClearOutputWindow()
    
    # Get the contingency analysis module
    contingency_analysis = app.GetFromStudyCase('*.ComSimoutage')
    contingency_analysis.iopt_Linear = 0
    contingency_analysis.loadmax = 50
    contingency_analysis.vlmin = 0.9
    contingency_analysis.vlmax = 1.1
    contingency_analysis.vmax_step = 5

    contingency_analysis.Execute()
    
    elmres = app.GetFromStudyCase('Contingency Analysis AC.ElmRes')
    comres = app.GetFromStudyCase('ComRes')
    comres.iopt_exp = 6
    comres.iopt_csel = 0
    comres.pResult = elmres
    comres.f_name = r'Resultados.csv'
    comres.Execute()

    print("Cargando resultados del archivo 'Resultados.csv'.")
    df = pd.read_csv('Resultados.csv', encoding='latin1', low_memory=False)
    return df

# %%
def process_cargabilidad(df):
    print("Procesando resultados de cargabilidad.")
    line_names = df.columns
    last_row = df.iloc[-1]
    line_load_df = pd.DataFrame({'Linea': line_names, 'Cargabilidad_Maxima': last_row})
    line_load_df = line_load_df[line_load_df['Cargabilidad_Maxima'] != '----']
    line_load_df['Cargabilidad_Maxima'] = pd.to_numeric(line_load_df['Cargabilidad_Maxima'], errors='coerce')
    line_load_df = line_load_df.dropna(subset=['Cargabilidad_Maxima'])
    line_load_df = line_load_df[~line_load_df['Linea'].str.contains('Study Cases', case=False)]
    line_load_df['Linea'] = line_load_df['Linea'].apply(lambda x: x.split('\\')[-1])
    line_load_df['Linea'] = line_load_df['Linea'].str.replace('.ElmLne', '', regex=False)
    
    # Eliminar las líneas que contienen '69 kV', '34.5 kV', o '4.16 kV'
    line_load_df = line_load_df[~line_load_df['Linea'].str.contains('69 kV|34.5 kV|4.16 kV', case=False)]
    
    line_load_df = line_load_df.sort_values(by='Cargabilidad_Maxima', ascending=False).reset_index(drop=True)
    print("Procesamiento de cargabilidad completado.")
    return line_load_df

# %%
def optimize_generators_for_substations(substations, network_data,hoja, initial_potencia=1, factor_potencia=0.95, max_cargabilidad=110, threshold_inconvergence=10):
    """
    Itera sobre cada subestación, agregando un generador, corriendo el análisis de contingencia y verificando el 
    máximo de potencia que puede soportar sin exceder el 110% de cargabilidad en ninguna línea.
    """
    results = []  # Lista para almacenar los resultados

    for substation in substations:
        current_potencia = initial_potencia
        print(f"Optimizando generador para la subestación '{substation}'.")

        # Crear generador inicial
        bus_voltage, p_gen, q_gen, static_generator, cubicle = create_static_generator(network_data, hoja, substation, current_potencia, factor_potencia)
        if static_generator is None:
            print(f"Error: No se pudo crear el generador en la subestación '{substation}'.")
            continue

        last_max_line_load = None

        while True:
            # Ejecutar el análisis de contingencia N-1 y obtener los resultados
            print("Ejecutando análisis de contingencia.")
            df = run_contingency_analysis()
            line_load_df = process_cargabilidad(df)

            # Verificar si alguna línea excede el 110% de cargabilidad
            max_line_load = line_load_df['Cargabilidad_Maxima'].max()
            max_line = line_load_df[line_load_df['Cargabilidad_Maxima'] == max_line_load]['Linea'].values[0]

            print(f"Subestación {substation}: Potencia actual = {current_potencia} MW, Max cargabilidad = {max_line_load}%, Línea = {max_line}")

            # Detectar inconvergencia si el incremento supera el umbral definido y si la cargabilidad es mayor a 110%
            if last_max_line_load is not None and (max_line_load - last_max_line_load) > threshold_inconvergence and max_line_load > max_cargabilidad:
                print(f"Advertencia: Inconvergencia detectada en la subestación '{substation}'. La cargabilidad saltó más del {threshold_inconvergence}% y superó el 110%. Aumentando potencia y volviendo a intentar.")
                # Aumentar la potencia en 1 MW y continuar
                current_potencia += 1
                potencia_aparente = current_potencia / factor_potencia
                potencia_reactiva_max = math.sqrt(potencia_aparente*2 - current_potencia*2)
                potencia_reactiva_min = -potencia_reactiva_max
                static_generator.SetAttribute('sgn', potencia_aparente)
                static_generator.SetAttribute('e:pgini', current_potencia)
                static_generator.SetAttribute('cQ_max', potencia_reactiva_max)
                static_generator.SetAttribute('cQ_min', potencia_reactiva_min)

                power_flow = app.GetFromStudyCase('ComLdf')
                power_flow.Execute()

                continue  # Seguir con la próxima iteración con la nueva potencia

            last_max_line_load = max_line_load

            if max_line_load > max_cargabilidad:
                print(f"Subestación {substation}: Potencia máxima segura = {current_potencia - 1} MW, Línea crítica = {max_line}")

                # Guardar el resultado en la lista
                results.append({
                    'Subestacion': substation,
                    'Potencia Maxima': current_potencia - 1,
                    'Linea Critica': max_line,
                    'Cargabilidad Maxima': last_max_line_load
                })

                # Eliminar el generador estático y el cubículo
                print(f"Eliminando generador estático y cubículo en la subestación '{substation}'.")
                static_generator.Delete()
                cubicle.Delete()

                break

            # Aumentar la potencia del generador estático existente
            current_potencia += 1
            potencia_aparente = current_potencia / factor_potencia
            potencia_reactiva_max = math.sqrt(potencia_aparente*2 - current_potencia*2)
            potencia_reactiva_min = -potencia_reactiva_max
            static_generator.SetAttribute('sgn', potencia_aparente)
            static_generator.SetAttribute('e:pgini', current_potencia)
            static_generator.SetAttribute('cQ_max', potencia_reactiva_max)
            static_generator.SetAttribute('cQ_min', potencia_reactiva_min)

            # Ejecutar el flujo de potencia nuevamente para aplicar los cambios
            power_flow = app.GetFromStudyCase('ComLdf')
            power_flow.Execute()

            print(f"Subestación {substation}: Aumentando potencia a {current_potencia} MW.")

    # Convertir los resultados a un DataFrame
    df_results = pd.DataFrame(results)
    print("Resultados finales:")
    print(df_results)

    return df_results

# %% [markdown]
# ---

# %%
import os
import sys

# Añadir la ruta del entorno de PowerFactory
dig_path = r'C:\Program Files\DIgSILENT\PowerFactory 2024 SP2\Python\3.11'
pf_enviroment(dig_path)
# Out:
# PowerFactory environment initialized with path: C:\Program Files\DIgSILENT\PowerFactory 2024 SP2\Python\3.11

# %%
import powerfactory as pf
import matplotlib.pyplot as plt

app = get_application()
# Nombre del proyecto a activar
project_name = "01. Caso Base_2028-Factor"
project = activate_project(project_name)
# Activate the desired study case
study_case_name = "2025"  # Replace with your specific case name
active_study_case = list_and_select_study_case(app, study_case_name)
# Activate the desired operation scenario
operation_scenario_name = "Ene_Bloque_3_dem_min_diurna_2025"
active_scenario = list_and_activate_operation_scenario(app, operation_scenario_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 4
#       1 import powerfactory as pf
#       2 import matplotlib.pyplot as plt
# ----> 4 app = get_application()
#       5 # Nombre del proyecto a activar
#       6 project_name = "01. Caso Base_2028-Factor"
#
# Cell In[16], line 6, in get_application()
#       2 """
#       3 Initializes the PowerFactory application instance.
#       4 """
#       5 app = pf.GetApplication()
# ----> 6 current_user = app.GetCurrentUser()
#       7 print(f"Initialize successfully and the  current user is {current_user}")
#       8 return app
#
# AttributeError: 'NoneType' object has no attribute 'GetCurrentUser'

# %%
import pandas as pd
import math

# Ejecución
print("Iniciando optimización de generadores en las subestaciones.")

substations = [
    "138 kV Puerto Plata 2 B1 Sec B",
    "138 kV Río San Juan",
    "138 kV SFM BP",
    "138 kV Sabaneta de Yasica",
    "138 kV Sajoma",
    "138 kV Salcedo",
    "138 kV Santiago Norte",
    "138 kV Santiago Rodríguez",
    "138 kV Solsur",
    "138 kV Sánchez",
    "138 kV Tavera B1",
    "138 kV Valverde Mao BT",
    "138 kV ZF Santiago B1",
    "Terminal Monte Cristi Solar Grupo 2",
    "bonao2",
    "bonao3",
    "canabacoa",
    "guayubin"
]

project = app.GetActiveProject()
network_data = project.GetContents('Network Model.IntPrjfolder\\Network Data', 1)[0]
hoja = 'NORTE'
initial_potencia = 1
factor_potencia = 0.95
max_cargabilidad = 110
threshold_inconvergence = 10
df_results = optimize_generators_for_substations(substations, network_data, hoja, initial_potencia, factor_potencia, max_cargabilidad, threshold_inconvergence)

print("Proceso completado.")
# Out:
# Iniciando optimización de generadores en las subestaciones.
# Optimizando generador para la subestación '138 kV Puerto Plata 2 B1 Sec B'.
# Creando generador estático en la barra '138 kV Puerto Plata 2 B1 Sec B' con potencia activa 1 MW y factor de potencia 0.95.
# Buscando hoja 'NORTE' en 'Network Data'.
# Barra '138 kV Puerto Plata 2 B1 Sec B' encontrada. Creando cubículo y generador estático.
# Cubículo creado en la barra '138 kV Puerto Plata 2 B1 Sec B' y conectado a la barra.
# Ejecutando flujo de potencia para la barra '138 kV Puerto Plata 2 B1 Sec B'.
# Generador estático creado: Voltaje barra = 1.0073839626498529, P generada = 0.9999999934463993, Q generada = -0.3244428274102031
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 1 MW, Max cargabilidad = 90.911021%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 2 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 2 MW, Max cargabilidad = 90.910328%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 3 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 3 MW, Max cargabilidad = 90.909411%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 4 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 4 MW, Max cargabilidad = 90.908386%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 5 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 5 MW, Max cargabilidad = 90.907297%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 6 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 6 MW, Max cargabilidad = 90.906168%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 7 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 7 MW, Max cargabilidad = 90.905012%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 8 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 8 MW, Max cargabilidad = 90.903838%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 9 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 9 MW, Max cargabilidad = 90.902647%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 10 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 10 MW, Max cargabilidad = 90.901454%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 11 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 11 MW, Max cargabilidad = 90.900256%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 12 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 12 MW, Max cargabilidad = 90.899057%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 13 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 13 MW, Max cargabilidad = 90.897858%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 14 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 14 MW, Max cargabilidad = 90.896662%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 15 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 15 MW, Max cargabilidad = 90.895469%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 16 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 16 MW, Max cargabilidad = 90.894281%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 17 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 17 MW, Max cargabilidad = 90.893098%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 18 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 18 MW, Max cargabilidad = 90.891923%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 19 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 19 MW, Max cargabilidad = 90.890754%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 20 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 20 MW, Max cargabilidad = 90.889594%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 21 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 21 MW, Max cargabilidad = 90.888442%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 22 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 22 MW, Max cargabilidad = 90.887298%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 23 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 23 MW, Max cargabilidad = 90.886164%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 24 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 24 MW, Max cargabilidad = 90.88504%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 25 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 25 MW, Max cargabilidad = 90.883926%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 26 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 26 MW, Max cargabilidad = 90.882823%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 27 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 27 MW, Max cargabilidad = 90.88173%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 28 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 28 MW, Max cargabilidad = 90.880647%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 29 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 29 MW, Max cargabilidad = 90.879576%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 30 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 30 MW, Max cargabilidad = 90.878517%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 31 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 31 MW, Max cargabilidad = 90.877468%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 32 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 32 MW, Max cargabilidad = 90.876432%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 33 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 33 MW, Max cargabilidad = 90.875407%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 34 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 34 MW, Max cargabilidad = 90.874394%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 35 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 35 MW, Max cargabilidad = 90.873394%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 36 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 36 MW, Max cargabilidad = 90.872405%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 37 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 37 MW, Max cargabilidad = 90.871429%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 38 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 38 MW, Max cargabilidad = 90.870465%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 39 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 39 MW, Max cargabilidad = 90.869514%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 40 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 40 MW, Max cargabilidad = 90.868576%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 41 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 41 MW, Max cargabilidad = 90.86765%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 42 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 42 MW, Max cargabilidad = 90.866737%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 43 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 43 MW, Max cargabilidad = 90.865837%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 44 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 44 MW, Max cargabilidad = 90.86495%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 45 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 45 MW, Max cargabilidad = 90.864075%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 46 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 46 MW, Max cargabilidad = 90.863214%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 47 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 47 MW, Max cargabilidad = 90.862366%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 48 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 48 MW, Max cargabilidad = 90.861531%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 49 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 49 MW, Max cargabilidad = 90.86071%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 50 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 50 MW, Max cargabilidad = 90.859901%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 51 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 51 MW, Max cargabilidad = 90.859106%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 52 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 52 MW, Max cargabilidad = 90.858324%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 53 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 53 MW, Max cargabilidad = 90.857556%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 54 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 54 MW, Max cargabilidad = 90.856801%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 55 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 55 MW, Max cargabilidad = 90.85606%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 56 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 56 MW, Max cargabilidad = 90.855332%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 57 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 57 MW, Max cargabilidad = 90.854617%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 58 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 58 MW, Max cargabilidad = 90.853917%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 59 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 59 MW, Max cargabilidad = 90.853229%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 60 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 60 MW, Max cargabilidad = 90.852556%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 61 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 61 MW, Max cargabilidad = 90.851896%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 62 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 62 MW, Max cargabilidad = 90.851249%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 63 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 63 MW, Max cargabilidad = 90.850617%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 64 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 64 MW, Max cargabilidad = 90.849998%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 65 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 65 MW, Max cargabilidad = 90.849393%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 66 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 66 MW, Max cargabilidad = 90.848801%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 67 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 67 MW, Max cargabilidad = 90.848224%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 68 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 68 MW, Max cargabilidad = 90.84766%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 69 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 69 MW, Max cargabilidad = 90.84711%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 70 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 70 MW, Max cargabilidad = 90.865681%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 71 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 71 MW, Max cargabilidad = 90.865164%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 72 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 72 MW, Max cargabilidad = 90.864662%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 73 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 73 MW, Max cargabilidad = 90.864173%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 74 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 74 MW, Max cargabilidad = 90.863698%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 75 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 75 MW, Max cargabilidad = 90.863238%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 76 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 76 MW, Max cargabilidad = 90.862791%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 77 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 77 MW, Max cargabilidad = 90.862358%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 78 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 78 MW, Max cargabilidad = 90.861939%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 79 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 79 MW, Max cargabilidad = 97.647772%, Línea = 138 kV Arroyo Hondo â Palamara_a
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 80 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 80 MW, Max cargabilidad = 89.810685%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 81 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 81 MW, Max cargabilidad = 89.810692%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 82 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 82 MW, Max cargabilidad = 90.820325%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 83 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 83 MW, Max cargabilidad = 89.810687%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 84 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 84 MW, Max cargabilidad = 89.810687%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 85 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 85 MW, Max cargabilidad = 89.810687%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 86 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 86 MW, Max cargabilidad = 89.810694%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 87 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 87 MW, Max cargabilidad = 89.810694%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 88 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 88 MW, Max cargabilidad = 89.810692%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 89 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 89 MW, Max cargabilidad = 145.894229%, Línea = 138 kV Haina â Itabo L2
# Advertencia: Inconvergencia detectada en la subestación '138 kV Puerto Plata 2 B1 Sec B'. La cargabilidad saltó más del 10% y superó el 110%. Aumentando potencia y volviendo a intentar.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 90 MW, Max cargabilidad = 89.810696%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 91 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 91 MW, Max cargabilidad = 89.810696%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 92 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 92 MW, Max cargabilidad = 89.810696%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 93 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 93 MW, Max cargabilidad = 89.81069%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 94 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 94 MW, Max cargabilidad = 89.810704%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 95 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 95 MW, Max cargabilidad = 89.810704%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 96 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 96 MW, Max cargabilidad = 89.810692%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 97 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 97 MW, Max cargabilidad = 90.816569%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 98 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 98 MW, Max cargabilidad = 89.810693%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 99 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 99 MW, Max cargabilidad = 118.741568%, Línea = 138 kV Cumayasa - SMP 2
# Advertencia: Inconvergencia detectada en la subestación '138 kV Puerto Plata 2 B1 Sec B'. La cargabilidad saltó más del 10% y superó el 110%. Aumentando potencia y volviendo a intentar.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 100 MW, Max cargabilidad = 90.816198%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 101 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 101 MW, Max cargabilidad = 90.816102%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 102 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 102 MW, Max cargabilidad = 90.816021%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 103 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 103 MW, Max cargabilidad = 90.815953%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 104 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 104 MW, Max cargabilidad = 90.8159%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 105 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 105 MW, Max cargabilidad = 90.815861%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 106 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 106 MW, Max cargabilidad = 90.815836%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 107 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 107 MW, Max cargabilidad = 90.815826%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 108 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 108 MW, Max cargabilidad = 90.815829%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 109 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 109 MW, Max cargabilidad = 90.815847%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 110 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 110 MW, Max cargabilidad = 90.815879%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 111 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 111 MW, Max cargabilidad = 90.815924%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 112 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 112 MW, Max cargabilidad = 90.872249%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Aumentando potencia a 113 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación 138 kV Puerto Plata 2 B1 Sec B: Potencia actual = 113 MW, Max cargabilidad = 90.816059%, Línea = 138 kV Bonao 3 â FALCONDO
# ...
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 616 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 616 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 617 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 617 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 618 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 618 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 619 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 619 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 620 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 620 MW, Max cargabilidad = 89.810607%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 621 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 621 MW, Max cargabilidad = 89.810605%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 622 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 622 MW, Max cargabilidad = 89.810605%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 623 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 623 MW, Max cargabilidad = 89.810606%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 624 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 624 MW, Max cargabilidad = 89.810607%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 625 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 625 MW, Max cargabilidad = 89.810604%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 626 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 626 MW, Max cargabilidad = 89.810604%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 627 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 627 MW, Max cargabilidad = 89.810606%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 628 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 628 MW, Max cargabilidad = 89.810602%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 629 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 629 MW, Max cargabilidad = 89.810602%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 630 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 630 MW, Max cargabilidad = 89.810609%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 631 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 631 MW, Max cargabilidad = 89.810605%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 632 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 632 MW, Max cargabilidad = 89.810601%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 633 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 633 MW, Max cargabilidad = 89.810605%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 634 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 634 MW, Max cargabilidad = 89.810605%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 635 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 635 MW, Max cargabilidad = 89.810607%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 636 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 636 MW, Max cargabilidad = 89.810601%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 637 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 637 MW, Max cargabilidad = 89.810601%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 638 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 638 MW, Max cargabilidad = 89.810605%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 639 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 639 MW, Max cargabilidad = 89.810606%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 640 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 640 MW, Max cargabilidad = 89.810604%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 641 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 641 MW, Max cargabilidad = 89.810604%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 642 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 642 MW, Max cargabilidad = 89.810601%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 643 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 643 MW, Max cargabilidad = 89.810607%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 644 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 644 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 645 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 645 MW, Max cargabilidad = 89.810604%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 646 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 646 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 647 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 647 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 648 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 648 MW, Max cargabilidad = 89.8106%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 649 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 649 MW, Max cargabilidad = 89.810599%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 650 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 650 MW, Max cargabilidad = 89.810598%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 651 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 651 MW, Max cargabilidad = 89.8106%, Línea = 138 kV Bonao 3 â FALCONDO
# Subestación Terminal Monte Cristi Solar Grupo 2: Aumentando potencia a 652 MW.
# Ejecutando análisis de contingencia.
# Iniciando análisis de contingencia N-1.
# Cargando resultados del archivo 'Resultados.csv'.
# Procesando resultados de cargabilidad.
# Procesamiento de cargabilidad completado.
# Subestación Terminal Monte Cristi Solar Grupo 2: Potencia actual = 652 MW, Max cargabilidad = 89.810603%, Línea = 138 kV Bonao 3 â FALCONDO
